# %% [markdown]
# <a href="https://colab.research.google.com/github/faezsghfi/content-agent/blob/master/src/content_agent/_4_fine_tuning/fine_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q \
    accelerate==0.33.0 \
    torch==2.4.0 \
    transformers==4.43.3 \
    datasets==2.20.0 \
    peft==0.12.0 \
    trl==0.9.6 \
    bitsandbytes==0.43.3 \
    comet-ml==3.44.3 \
    flash-attn==2.3.6 \
    unsloth==2024.9.post2
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==2.4.0 (from versions: 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0, 2.12.0, 2.12.1, 2.13.0, 2.14.0)
# ERROR: No matching distribution found for torch==2.4.0
